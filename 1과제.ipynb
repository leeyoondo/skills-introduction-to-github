# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a = 'str'
b = 123
c = True

print(type(a), type(b), type(c))
# Out:
# <class 'str'> <class 'int'> <class 'bool'>

# %%
a = 7
b = 4

print(a**b, a%b, a//b, a/b)
# Out:
# 2401 3 1 1.75

# %%
ai_math = 79
machine_learning = 83
deep_learning = 89
algorithm = 76

average_score = (ai_math + machine_learning + deep_learning + algorithm) / 4
print(average_score)
# Out:
# 81.75

# %%
str_ai = 'Gwang ju'

print(str_ai[6], str_ai[3:7])
# Out:
# j ng j

# %%
list_ai = [1, 2, 3, ['a', 'b', 'c']]

print(list_ai[3])
# Out:
# ['a', 'b', 'c']

# %%
list_ai = ['GSM', 'School', ['Software', 'Gwang', ['Ju', 'Maister']]]

software = list_ai[2][0]
maister = list_ai[2][2][1]
print(software + maister)
# Out:
# SoftwareMaister

# %%
list_ai = ['교', '학', '등', '고', '터', '스', '이', '마', '어', '웨', '트', '소', '주', '광']

list_ai.reverse()
print(list_ai)
# Out:
# ['광', '주', '소', '트', '웨', '어', '마', '이', '스', '터', '고', '등', '학', '교']

# %%
str_ai = '광주 소프트웨어 마이스터 고등학교'
str_ai2 = '광주;소프트웨어;마이스터;고등학교'

split_str_ai = str_ai.split(' ')
split_str_ai2 = str_ai2.split(';')
print(split_str_ai, split_str_ai2)
# Out:
# ['광주', '소프트웨어', '마이스터', '고등학교'] ['광주', '소프트웨어', '마이스터', '고등학교']

# %%
str_ai = '괌주 소프트웨어마이스터고등학교'

corrected_str_ai = str_ai.replace('괌주', '광주')
print(corrected_str_ai)
# Out:
# 광주 소프트웨어마이스터고등학교

# %%
scores = [78, 83, 89, 76]

scores.sort(reverse=True)
print(scores)
# Out:
# [89, 83, 78, 76]

# %%
list_ai = [78,77,54,55,87]
int_ai = 98

list_ai.append(int_ai)
print(list_ai)
# Out:
# [78, 77, 54, 55, 87, 98]

# %%
list_ai = ['소프트웨어', '광주', '마이스터', '학교', '고등']

print(len(list_ai))
# Out:
# 5

# %%
list_ai = ['소프트웨어', '광주', '마이스터', '학교', '고등']

print(list_ai.index('학교'))
# Out:
# 3
